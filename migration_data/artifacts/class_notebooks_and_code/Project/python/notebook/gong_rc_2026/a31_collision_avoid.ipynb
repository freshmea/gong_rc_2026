# %%
from pop import Pilot

cam=Pilot.Camera(width=300, height=300)
cam.show()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…

# %%
cam.stop()

# %%
dataCollector=Pilot.Data_Collector(Pilot.Collision_Avoid, camera=cam)

# %%
dataCollector.show()
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x0…
# HBox(children=(IntText(value=0, layout=Layout(height='64px', width='128px')), Button(button_style='success', d…
# HBox(children=(IntText(value=0, layout=Layout(height='64px', width='128px')), Button(button_style='danger', de…
# <style>.joystick_focused{ cursor:grabbing !important;}    .joystick_background{user-select: none;        background: #fff3f3;        border: 1px solid #ffa29e;        border-radius: 50%;        height: 12em;        width: 12em;    margin:2.5em;}    .joystick_stick{cursor:grab; user-select: none;        background: #F74138;        border-radius: 50%;        box-shadow: 0.375em 0.375em 0 0 rgba(15, 28, 63, 0.125);        height: 5em;        width: 5em;        transform: translate(50%,50%);    }</style><div><div id="joystick_background_4CE26521053FF8" class="joystick_background">    <div id="joystick_stick_4CE26521053FF8" class="joystick_stick" style="position:absolute" onmousedown="start_joystick_4CE26521053FF8(this); joystick_focus_4CE26521053FF8(this);" ondrag="joystick_4CE26521053FF8(e)" onmouseup="reset_joystick_4CE26521053FF8(this); joystick_disfocus_4CE26521053FF8(this);"></div></div></div><script> X=0; Y=0; function joystick_focus_4CE26521053FF8(e){ e.classList.add("joystick_focused");} function joystick_disfocus_4CE26521053FF8(e){ e.classList.remove("joystick_focused");}    var port_4CE26521053FF8=8886;    var sock_4CE26521053FF8=new WebSocket("ws://"+window.location.hostname+":"+port_4CE26521053FF8);    var sw_4CE26521053FF8=false;    var preX_4CE26521053FF8, preY_4CE26521053FF8, X_4CE26521053FF8, Y_4CE26521053FF8, nX_4CE26521053FF8, nY_4CE26521053FF8;    var back_4CE26521053FF8=document.getElementById("joystick_background_4CE26521053FF8");    var stick_4CE26521053FF8=document.getElementById("joystick_stick_4CE26521053FF8");    var back_width_4CE26521053FF8=back_4CE26521053FF8.offsetWidth;    var back_height_4CE26521053FF8=back_4CE26521053FF8.offsetHeight;    var stick_width_4CE26521053FF8=stick_4CE26521053FF8.offsetWidth;    var stick_height_4CE26521053FF8=stick_4CE26521053FF8.offsetHeight;  intlog_4CE26521053FF8=Date.now();  setInterval(()=>{try{if (parseFloat(sX_4CE26521053FF8)==0 && parseFloat(sY_4CE26521053FF8)==0) {if (Date.now()-intlog_4CE26521053FF8<500) sock_4CE26521053FF8.send("j," + sX_4CE26521053FF8 + "," + sY_4CE26521053FF8);}else{ sock_4CE26521053FF8.send("j," + sX_4CE26521053FF8 + "," + sY_4CE26521053FF8); intlog_4CE26521053FF8=Date.now();}}catch{console.log("Waiting to connect...");}},50); function move_4CE26521053FF8(evt){        X=evt.clientX;        Y=evt.clientY;        if(sw_4CE26521053FF8){            nX_4CE26521053FF8+=X-preX_4CE26521053FF8;            nY_4CE26521053FF8+=Y-preY_4CE26521053FF8;            preX_4CE26521053FF8=X;            preY_4CE26521053FF8=Y;            if (nX_4CE26521053FF8>back_width_4CE26521053FF8-stick_width_4CE26521053FF8/2) nX_4CE26521053FF8=back_width_4CE26521053FF8-stick_width_4CE26521053FF8/2;            else if (nX_4CE26521053FF8<-stick_width_4CE26521053FF8/2) nX_4CE26521053FF8=-stick_width_4CE26521053FF8/2;            if (nY_4CE26521053FF8>back_height_4CE26521053FF8-stick_height_4CE26521053FF8/2) nY_4CE26521053FF8=back_height_4CE26521053FF8-stick_height_4CE26521053FF8/2;            else if (nY_4CE26521053FF8<-stick_height_4CE26521053FF8/2) nY_4CE26521053FF8=-stick_height_4CE26521053FF8/2;            sX_4CE26521053FF8=(nX_4CE26521053FF8+stick_width_4CE26521053FF8/2-back_width_4CE26521053FF8/2)/(back_width_4CE26521053FF8/2);            sY_4CE26521053FF8=-(nY_4CE26521053FF8+stick_height_4CE26521053FF8/2-back_height_4CE26521053FF8/2)/(back_height_4CE26521053FF8/2);                        /*sock_4CE26521053FF8.send("j,"+sX_4CE26521053FF8+","+sY_4CE26521053FF8);*/            stick_4CE26521053FF8.style.transform="translate("+nX_4CE26521053FF8+"px,"+nY_4CE26521053FF8+"px)";        }    };    function up_4CE26521053FF8(){joystick_disfocus_4CE26521053FF8(stick_4CE26521053FF8);        if(sw_4CE26521053FF8){            sw_4CE26521053FF8=false;            reset_joystick_4CE26521053FF8(stick_4CE26521053FF8);        }    };    function start_joystick_4CE26521053FF8(e){window.onmousemove=move_4CE26521053FF8; window.onmouseup=up_4CE26521053FF8;        preX_4CE26521053FF8=X;        preY ...

# %%
CA=Pilot.Collision_Avoid(cam)
CA.load_datasets()
# Out:
# Label(value='Loading datasets...')
# Label(value='Creating a new model...')
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /home/soda/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# 100.0%

# %%
CA.train(times=10)
# Out:
# VBox(children=(HBox(children=(FloatProgress(value=0.0, description='Total'), Label(value='0%'))), HBox(childre…
# 0  step accuracy : 0.0%
# 1  step accuracy : 0.0%
# 2  step accuracy : 0.0%
# 3  step accuracy : 0.0%
# 4  step accuracy : 0.0%
# 5  step accuracy : 0.0%
# 6  step accuracy : 0.0%
# 7  step accuracy : 0.0%
# 8  step accuracy : 0.0%
# 9  step accuracy : 0.0%

# %%
value=CA.run()
print(value)
# Out:
# 2.7554149825519125e-13

# %%
CA.show()
# Out:
# HBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C…

# %%
def is_blocked(value):
	print(value>0.5)

value=CA.run(callback=is_blocked)
print(value)
# Out:
# False
# 4.802690363459039e-14
